# %%
# Data manipulation
import numpy as np
import pandas as pd
pd.options.display.max_rows = 100

# Modeling
from matrix_factorization import BaselineModel, KernelMF, train_update_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# Other
import os
import random
import sys

# Reload imported code 
# %load_ext autoreload
# %autoreload 2

# Print all output
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
    
rand_seed = 2
np.random.seed(rand_seed)
random.seed(rand_seed)

# %% [markdown]
# # Load data

# %% [markdown]
# **Movie data found here https://grouplens.org/datasets/movielens/**

# %%
cols = ['user_id', 'item_id', 'rating', 'timestamp']
# movie_data = pd.read_csv('../data/ml-1m/ratings.dat', names = cols, sep = '::', usecols=[0, 1, 2], engine='python')
movie_data = pd.read_csv('../data/ml-100k/u.data', names = cols, sep = '\t', usecols=[0, 1, 2], engine='python')

X = movie_data[['user_id', 'item_id']]
y = movie_data['rating']

# Prepare data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Prepare data for online learning
X_train_initial, y_train_initial, X_train_update, y_train_update, X_test_update, y_test_update = train_update_test_split(movie_data, frac_new_users=0.2)

movie_data.head(10)
# Out:
#    user_id  item_id  rating
# 0      196      242       3
# 1      186      302       3
# 2       22      377       1
# 3      244       51       2
# 4      166      346       1
# 5      298      474       4
# 6      115      265       2
# 7      253      465       5
# 8      305      451       3
# 9        6       86       3

# %% [markdown]
# # Simple model with global mean

# %% [markdown]
# This is similar to just the global standard deviation

# %%
global_mean = y_train.mean()
pred = [global_mean for _ in range(y_test.shape[0])]

mse = mean_squared_error(y_test, pred)
rmse = mse ** 0.5

print(f'\nTest RMSE: {rmse:4f}')
# Out:
# Test RMSE: 1.120652

# %% [markdown]
# # Baseline Model with biases

# %% [markdown]
# ## SGD

# %%
# %%time

baseline_model = BaselineModel(method='sgd', n_epochs = 20, reg = 0.005, lr = 0.01, verbose=1)
baseline_model.fit(X_train, y_train)

pred = baseline_model.predict(X_test)
mse = mean_squared_error(y_test, pred)
rmse = mse ** 0.5

print(f'\nTest RMSE: {rmse:.4f}')
# Out:
# Epoch  1 / 20  -  train_rmse: 0.9686423944865309
# Epoch  2 / 20  -  train_rmse: 0.945454644947265
# Epoch  3 / 20  -  train_rmse: 0.9351504213186972
# Epoch  4 / 20  -  train_rmse: 0.9295761495251743
# Epoch  5 / 20  -  train_rmse: 0.9258745652248292
# Epoch  6 / 20  -  train_rmse: 0.9236050331012716
# Epoch  7 / 20  -  train_rmse: 0.9218177186021692
# Epoch  8 / 20  -  train_rmse: 0.9207562141689237
# Epoch  9 / 20  -  train_rmse: 0.9197623029873546
# Epoch  10 / 20  -  train_rmse: 0.9189995712834659
# Epoch  11 / 20  -  train_rmse: 0.918451462605598
# Epoch  12 / 20  -  train_rmse: 0.9180495122471143
# Epoch  13 / 20  -  train_rmse: 0.9175399439606876
# Epoch  14 / 20  -  train_rmse: 0.9171618159264271
# Epoch  15 / 20  -  train_rmse: 0.9169935669356354
# Epoch  16 / 20  -  train_rmse: 0.9168335455723187
# Epoch  17 / 20  -  train_rmse: 0.9164828124223623
# Epoch  18 / 20  -  train_rmse: 0.9164100229768548
# Epoch  19 / 20  -  train_rmse: 0.9162339753489479
# Epoch  20 / 20  -  train_rmse: 0.9159991874080741
#
# Test RMSE: 0.9289
# CPU times: user 1.48 s, sys: 137 ms, total: 1.61 s
# Wall time: 1.82 s
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 144.  700.  918. ... 1073.  575.  185.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)

# %%
baseline_model.recommend(user=200)
# Out:
#      user_id  item_id  rating_pred
# 388      200      408          5.0
# 212      200      169          5.0
# 790      200      114          5.0
# 378      200      318          5.0
# 281      200      483          5.0
# 338      200       64          5.0
# 726      200      513          5.0
# 988      200     1449          5.0
# 188      200      178          5.0
# 54       200      603          5.0

# %% [markdown]
# ## ALS

# %%
# %%time

baseline_model = BaselineModel(method='als', n_epochs = 20, reg = 0.5, verbose=1)
baseline_model.fit(X_train, y_train)

pred = baseline_model.predict(X_test)
mse = mean_squared_error(y_test, pred)
rmse = mse ** 0.5

print(f'\nTest RMSE: {rmse:.4f}')
# Out:
# Epoch  1 / 20  -  train_rmse: 0.9312489364350157
# Epoch  2 / 20  -  train_rmse: 0.9144875214764501
# Epoch  3 / 20  -  train_rmse: 0.9134856911195807
# Epoch  4 / 20  -  train_rmse: 0.9133800448918423
# Epoch  5 / 20  -  train_rmse: 0.9133615794862777
# Epoch  6 / 20  -  train_rmse: 0.9133565857003941
# Epoch  7 / 20  -  train_rmse: 0.9133544601244424
# Epoch  8 / 20  -  train_rmse: 0.9133531004630441
# Epoch  9 / 20  -  train_rmse: 0.9133519902067218
# Epoch  10 / 20  -  train_rmse: 0.9133509792033206
# Epoch  11 / 20  -  train_rmse: 0.9133500175542733
# Epoch  12 / 20  -  train_rmse: 0.9133490869495551
# Epoch  13 / 20  -  train_rmse: 0.9133481801287349
# Epoch  14 / 20  -  train_rmse: 0.9133472939684136
# Epoch  15 / 20  -  train_rmse: 0.9133464269599311
# Epoch  16 / 20  -  train_rmse: 0.9133455782426871
# Epoch  17 / 20  -  train_rmse: 0.9133447472230197
# Epoch  18 / 20  -  train_rmse: 0.9133439334215674
# Epoch  19 / 20  -  train_rmse: 0.9133431364114416
# Epoch  20 / 20  -  train_rmse: 0.9133423557930989
#
# Test RMSE: 0.9294
# CPU times: user 219 ms, sys: 3.89 ms, total: 223 ms
# Wall time: 223 ms
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 645. 1111.  518. ...  910.  863.   76.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)

# %% [markdown]
# ## Updating with new users

# %%
baseline_model = BaselineModel(method='sgd', n_epochs = 20, lr=0.01, reg = 0.05, verbose=1)
baseline_model.fit(X_train_initial, y_train_initial)
# Out:
# Epoch  1 / 20  -  train_rmse: 0.964686930194181
# Epoch  2 / 20  -  train_rmse: 0.9427319362325008
# Epoch  3 / 20  -  train_rmse: 0.9333556569724756
# Epoch  4 / 20  -  train_rmse: 0.9281134929077341
# Epoch  5 / 20  -  train_rmse: 0.924616252210722
# Epoch  6 / 20  -  train_rmse: 0.9224724060783375
# Epoch  7 / 20  -  train_rmse: 0.9209601096060667
# Epoch  8 / 20  -  train_rmse: 0.9197715584060696
# Epoch  9 / 20  -  train_rmse: 0.9189359161243891
# Epoch  10 / 20  -  train_rmse: 0.9181645778586561
# Epoch  11 / 20  -  train_rmse: 0.9176273893537576
# Epoch  12 / 20  -  train_rmse: 0.9170737789422722
# Epoch  13 / 20  -  train_rmse: 0.9168711098095811
# Epoch  14 / 20  -  train_rmse: 0.9163025570472149
# Epoch  15 / 20  -  train_rmse: 0.9162865690867323
# Epoch  16 / 20  -  train_rmse: 0.9159995138329357
# Epoch  17 / 20  -  train_rmse: 0.9161785855136518
# Epoch  18 / 20  -  train_rmse: 0.9156641482148411
# Epoch  19 / 20  -  train_rmse: 0.9155810137145801
# Epoch  20 / 20  -  train_rmse: 0.9154245995660817
# BaselineModel(n_epochs=20, reg=0.05)

# %%
# %%time
baseline_model.update_users(X_train_update, y_train_update, n_epochs=20, lr=0.001, verbose=1)
pred = baseline_model.predict(X_test_update)
mse = mean_squared_error(y_test_update, pred)
rmse = mse ** 0.5

print(f'\nTest RMSE: {rmse:.4f}')
# Out:
# Epoch  1 / 20  -  train_rmse: 1.0195780914433232
# Epoch  2 / 20  -  train_rmse: 1.002900083577449
# Epoch  3 / 20  -  train_rmse: 0.9904109648728807
# Epoch  4 / 20  -  train_rmse: 0.9809717028029952
# Epoch  5 / 20  -  train_rmse: 0.9736893030283219
# Epoch  6 / 20  -  train_rmse: 0.9679197401301578
# Epoch  7 / 20  -  train_rmse: 0.9633203390747541
# Epoch  8 / 20  -  train_rmse: 0.959540548341889
# Epoch  9 / 20  -  train_rmse: 0.9564021050290984
# Epoch  10 / 20  -  train_rmse: 0.9537597542578576
# Epoch  11 / 20  -  train_rmse: 0.9515121413845853
# Epoch  12 / 20  -  train_rmse: 0.9495673919686078
# Epoch  13 / 20  -  train_rmse: 0.9478626173370919
# Epoch  14 / 20  -  train_rmse: 0.9463652169346675
# Epoch  15 / 20  -  train_rmse: 0.9450349543415082
# Epoch  16 / 20  -  train_rmse: 0.9438493769950023
# Epoch  17 / 20  -  train_rmse: 0.9427772080766882
# Epoch  18 / 20  -  train_rmse: 0.941809492904174
# Epoch  19 / 20  -  train_rmse: 0.9409270128310528
# Epoch  20 / 20  -  train_rmse: 0.9401240030612253
#
# Test RMSE: 0.9486
# CPU times: user 137 ms, sys: 1.45 ms, total: 139 ms
# Wall time: 138 ms
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[198. 354. 862. ... 146.  23. 273.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)

# %% [markdown]
# # Matrix Factorization

# %% [markdown]
# ## Linear Kernel

# %%
# %%time 
matrix_fact = KernelMF(n_epochs = 20, n_factors = 100, verbose = 1, lr = 0.001, reg = 0.005)
matrix_fact.fit(X_train, y_train)

pred = matrix_fact.predict(X_test)
mse = mean_squared_error(y_test, pred)
rmse = mse ** 0.5

print(f'\nTest RMSE: {rmse:.4f}')
# Out:
# Epoch  1 / 20  -  train_rmse: 1.0801251099047668
# Epoch  2 / 20  -  train_rmse: 1.047348115694743
# Epoch  3 / 20  -  train_rmse: 1.0245119050469507
# Epoch  4 / 20  -  train_rmse: 1.007507162802038
# Epoch  5 / 20  -  train_rmse: 0.9942485994051239
# Epoch  6 / 20  -  train_rmse: 0.9835016540514843
# Epoch  7 / 20  -  train_rmse: 0.9745253004390946
# Epoch  8 / 20  -  train_rmse: 0.9668164141621324
# Epoch  9 / 20  -  train_rmse: 0.9600677268374247
# Epoch  10 / 20  -  train_rmse: 0.9540559701577022
# Epoch  11 / 20  -  train_rmse: 0.9486189249653856
# Epoch  12 / 20  -  train_rmse: 0.9436393059320735
# Epoch  13 / 20  -  train_rmse: 0.9390301282567551
# Epoch  14 / 20  -  train_rmse: 0.9347253204516975
# Epoch  15 / 20  -  train_rmse: 0.9306723288834663
# Epoch  16 / 20  -  train_rmse: 0.9268332372919156
# Epoch  17 / 20  -  train_rmse: 0.9231727685802924
# Epoch  18 / 20  -  train_rmse: 0.9196608757760587
# Epoch  19 / 20  -  train_rmse: 0.9162785037341064
# Epoch  20 / 20  -  train_rmse: 0.9130054151762321
#
# Test RMSE: 0.9534
# CPU times: user 1.42 s, sys: 67.3 ms, total: 1.49 s
# Wall time: 1.51 s
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 616.  581.  212. ...  796. 1194.  152.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)

# %% [markdown]
# ## Getting list of recommendations for a user

# %%
user = 200
items_known = X_train.query('user_id == @user')['item_id']
matrix_fact.recommend(user=user, items_known=items_known)
# Out:
#      user_id  item_id  rating_pred
# 37       200       64     5.000000
# 242      200      357     4.952953
# 11       200      127     4.914617
# 61       200      272     4.903618
# 395      200      480     4.837317
# 710      200      479     4.837083
# 275      200       12     4.814873
# 655      200      427     4.808881
# 55       200      511     4.805896
# 144      200      285     4.797134

# %% [markdown]
# ## Updating with new users

# %%
matrix_fact = KernelMF(n_epochs = 20, n_factors = 100, verbose = 1, lr = 0.001, reg = 0.005)
matrix_fact.fit(X_train_initial, y_train_initial)
# Out:
# Epoch  1 / 20  -  train_rmse: 1.070538707802871
# Epoch  2 / 20  -  train_rmse: 1.0382159716897121
# Epoch  3 / 20  -  train_rmse: 1.0162031280663388
# Epoch  4 / 20  -  train_rmse: 0.9999204990611213
# Epoch  5 / 20  -  train_rmse: 0.9872294909194177
# Epoch  6 / 20  -  train_rmse: 0.9769249789892207
# Epoch  7 / 20  -  train_rmse: 0.9682958041917087
# Epoch  8 / 20  -  train_rmse: 0.9608895565638447
# Epoch  9 / 20  -  train_rmse: 0.9543889595540945
# Epoch  10 / 20  -  train_rmse: 0.948578659813844
# Epoch  11 / 20  -  train_rmse: 0.9433055970501156
# Epoch  12 / 20  -  train_rmse: 0.938461641360533
# Epoch  13 / 20  -  train_rmse: 0.9339642006418014
# Epoch  14 / 20  -  train_rmse: 0.9297502588547513
# Epoch  15 / 20  -  train_rmse: 0.9257709608859865
# Epoch  16 / 20  -  train_rmse: 0.9219862741469365
# Epoch  17 / 20  -  train_rmse: 0.9183655667900865
# Epoch  18 / 20  -  train_rmse: 0.9148845245960727
# Epoch  19 / 20  -  train_rmse: 0.9115179681015021
# Epoch  20 / 20  -  train_rmse: 0.9082505316006381
# KernelMF(gamma=0.01, lr=0.001, n_epochs=20, reg=0.005)

# %%
# %%time
# Update model with new users
matrix_fact.update_users(X_train_update, y_train_update, lr=0.001, n_epochs=20, verbose=1)
pred = matrix_fact.predict(X_test_update)
mse = mean_squared_error(y_test_update, pred)
rmse = mse ** 0.5

print(f'\nTest RMSE: {rmse:.4f}')
# Out:
# Epoch  1 / 20  -  train_rmse: 1.0397450554800525
# Epoch  2 / 20  -  train_rmse: 1.0204337379810584
# Epoch  3 / 20  -  train_rmse: 1.0058096346155325
# Epoch  4 / 20  -  train_rmse: 0.9945487509230668
# Epoch  5 / 20  -  train_rmse: 0.9856788852385475
# Epoch  6 / 20  -  train_rmse: 0.9785502807148969
# Epoch  7 / 20  -  train_rmse: 0.9727211384013853
# Epoch  8 / 20  -  train_rmse: 0.9678294345771077
# Epoch  9 / 20  -  train_rmse: 0.9636503985446767
# Epoch  10 / 20  -  train_rmse: 0.960009401734517
# Epoch  11 / 20  -  train_rmse: 0.9567808372197321
# Epoch  12 / 20  -  train_rmse: 0.9538862549785115
# Epoch  13 / 20  -  train_rmse: 0.9512620535601249
# Epoch  14 / 20  -  train_rmse: 0.9488473078085282
# Epoch  15 / 20  -  train_rmse: 0.9466082136054945
# Epoch  16 / 20  -  train_rmse: 0.9445122840152649
# Epoch  17 / 20  -  train_rmse: 0.9425388443923118
# Epoch  18 / 20  -  train_rmse: 0.9406656946030653
# Epoch  19 / 20  -  train_rmse: 0.9388828051919528
# Epoch  20 / 20  -  train_rmse: 0.9371795087892466
#
# Test RMSE: 0.9677
# CPU times: user 645 ms, sys: 7.78 ms, total: 653 ms
# Wall time: 668 ms
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 30. 546. 385. ... 556. 469. 451.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)

# %% [markdown]
# ## Sigmoid kernel

# %%
# %%time 
matrix_fact = KernelMF(n_epochs = 20, n_factors = 100, verbose = 1, lr = 0.01, reg = 0.005, kernel='sigmoid')
matrix_fact.fit(X_train, y_train)

pred = matrix_fact.predict(X_test)
mse = mean_squared_error(y_test, pred)
rmse = mse ** 0.5

print(f'\nTest RMSE: {rmse:.4f}')
# Out:
# Epoch  1 / 20  -  train_rmse: 1.7254805205751333
# Epoch  2 / 20  -  train_rmse: 1.700298323525964
# Epoch  3 / 20  -  train_rmse: 1.662238337802511
# Epoch  4 / 20  -  train_rmse: 1.6209458229579268
# Epoch  5 / 20  -  train_rmse: 1.5756407606745388
# Epoch  6 / 20  -  train_rmse: 1.523380376461499
# Epoch  7 / 20  -  train_rmse: 1.46584264477677
# Epoch  8 / 20  -  train_rmse: 1.4093903037737305
# Epoch  9 / 20  -  train_rmse: 1.3583723368736296
# Epoch  10 / 20  -  train_rmse: 1.3132907595663301
# Epoch  11 / 20  -  train_rmse: 1.2739409058784805
# Epoch  12 / 20  -  train_rmse: 1.2393439462737148
# Epoch  13 / 20  -  train_rmse: 1.2087482554275188
# Epoch  14 / 20  -  train_rmse: 1.1814329531446852
# Epoch  15 / 20  -  train_rmse: 1.1569723519850141
# Epoch  16 / 20  -  train_rmse: 1.1349239855313502
# Epoch  17 / 20  -  train_rmse: 1.1148887056124974
# Epoch  18 / 20  -  train_rmse: 1.096588994313544
# Epoch  19 / 20  -  train_rmse: 1.079775939120299
# Epoch  20 / 20  -  train_rmse: 1.0642499147786675
#
# Test RMSE: 1.1110
# CPU times: user 435 ms, sys: 2.89 ms, total: 438 ms
# Wall time: 438 ms
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[136.  19. 572. ...  36. 790.  56.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)

# %% [markdown]
# ## RBF Kernel

# %%
# %%time 
matrix_fact = KernelMF(n_epochs = 20, n_factors = 100, verbose = 1, lr = 0.5, reg = 0.005, kernel='rbf')
matrix_fact.fit(X_train, y_train)

pred = matrix_fact.predict(X_test)
mse = mean_squared_error(y_test, pred)
rmse = mse ** 0.5

print(f'\nTest RMSE: {rmse:.4f}')
# Out:
# Epoch  1 / 20  -  train_rmse: 1.2622950262198738
# Epoch  2 / 20  -  train_rmse: 1.1102992660855353
# Epoch  3 / 20  -  train_rmse: 1.0463669013800458
# Epoch  4 / 20  -  train_rmse: 1.0040136262041024
# Epoch  5 / 20  -  train_rmse: 0.9735098603587192
# Epoch  6 / 20  -  train_rmse: 0.9523727245812303
# Epoch  7 / 20  -  train_rmse: 0.9348634981032051
# Epoch  8 / 20  -  train_rmse: 0.9229699775438122
# Epoch  9 / 20  -  train_rmse: 0.913491431161034
# Epoch  10 / 20  -  train_rmse: 0.9033072087853409
# Epoch  11 / 20  -  train_rmse: 0.9002857264773999
# Epoch  12 / 20  -  train_rmse: 0.8961511599895111
# Epoch  13 / 20  -  train_rmse: 0.8927527284373504
# Epoch  14 / 20  -  train_rmse: 0.8900681688285926
# Epoch  15 / 20  -  train_rmse: 0.8872865719163149
# Epoch  16 / 20  -  train_rmse: 0.8851759267879175
# Epoch  17 / 20  -  train_rmse: 0.8838043754937456
# Epoch  18 / 20  -  train_rmse: 0.8824818565867462
# Epoch  19 / 20  -  train_rmse: 0.8837292387381509
# Epoch  20 / 20  -  train_rmse: 0.8810714770613943
#
# Test RMSE: 0.9678
# CPU times: user 863 ms, sys: 6.92 ms, total: 870 ms
# Wall time: 872 ms
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[532. 715. 416. ... 412. 439. 429.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)

# %% [markdown]
# # Scikit-learn compatability

# %%
from sklearn.model_selection import GridSearchCV, ParameterGrid

param_grid = {
    'kernel': ['linear', 'sigmoid', 'rbf'],
    'n_factors': [10, 20, 50],
    'n_epochs': [10, 20, 50],
    'reg': [0, 0.005, 0.1]
}

grid_search = GridSearchCV(KernelMF(verbose=0), scoring = 'neg_root_mean_squared_error', param_grid=param_grid, n_jobs=-1, cv=5, verbose=1)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1003.  180.  339. ...  264.   14.  255.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[395. 368.  94. ... 139. 575.  34.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1124.   37.  198. ...  316.  461.  469.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[608. 138. 587. ... 947. 326. 128.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 23. 503. 467. ... 168. 294. 486.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[727. 225. 164. ... 354. 775.   8.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 963.   93.  765. ...  223.  281. 1466.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 151.  280. 1153. ...  334.  454.  533.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 499.  381.  242. ...  580. 1053.  193.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 270.   89.  356. ...  910.  179. 1017.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1166.   13.  765. ...  558.  359. 1518.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 38. 762. 924. ... 212. 269. 681.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[216.  32. 277. ... 109. 236. 357.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 375.  383. 1037. ...  155.  698.  109.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1187.  313.  793. ...  437.   91. 1319.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[   7.  239. 1107. ...   64.  515.   22.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[425.   8. 971. ... 190. 148. 864.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[642. 106. 123. ... 458. 167. 307.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 24.  44.   6. ...  11. 464. 183.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[771. 183.  64. ...  91. 530. 456.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 531.  422.  690. ...  637.    8. 1391.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[771. 160. 155. ...  10. 660. 676.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 570.   66. 1020. ...    6.  385.  251.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[158. 807. 814. ... 216.   0. 281.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[805. 778. 999. ...  39.  69. 281.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[353. 266. 875. ... 217. 140. 331.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1058.   45.   35. ...  306.  665.  179.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1087.   18.   99. ...  742.  132.  486.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 290.  282.  305. ...   68.  187. 1581.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 158.   24. 1365. ...  101.   59.  582.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[522. 412.  45. ...  43. 847. 387.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[343.  32. 100. ...   8. 390. 239.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[124. 434. 795. ... 218. 858. 216.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[104. 113. 790. ...  84.  28.  62.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[  16.  476.  406. ...   92.   94. 1577.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[822.  97.  90. ...  43. 415. 203.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[216.   8. 237. ... 307. 364. 150.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 796.  195.  347. ...  642.  237. 1479.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[726.  43. 948. ... 293. 396. 558.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[128. 171. 177. ... 391. 174. 875.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 980.  105.  386. ...  246. 1093.  216.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[720. 688.  42. ... 192. 156. 357.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 828.  294.  414. ...    8.   97. 1566.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[960.  47. 221. ... 375. 490. 323.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[  41.  438. 1113. ...  141.  221.  325.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1085.  145.  191. ...  273.  325.  547.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[359. 546. 319. ... 384. 102. 435.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[937. 233. 277. ... 198. 134. 443.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 975.  191.  314. ...  403.  479. 1592.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 464.  336.  286. ...  448. 1155.  434.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[755. 145. 632. ... 957. 150. 245.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[185. 494. 112. ...  32.  95.  90.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[504. 237. 690. ... 566. 833. 152.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[839. 190. 139. ... 154. 158. 115.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[  34.  558. 1249. ...  107.  196.  536.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1168.  249.  400. ...  491.   30. 1329.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 746.  251.  346. ...  661.   70. 1498.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[448. 204. 333. ...  26. 715. 213.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 163.  772. 1187. ...  328.  654.  276.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[136. 308. 439. ... 137.  67. 121.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[371. 280. 385. ... 667. 127. 251.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[399. 257. 123. ... 200. 130.  90.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[473. 493. 285. ... 189.  88. 161.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[938.  67. 520. ... 232. 474. 503.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 149.  292. 1062. ...  230.  131.  789.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1174.   78.   40. ...  112.  141.  108.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[891.  25. 134. ... 176.  86. 380.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[398. 643. 443. ... 468. 237. 447.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 149.  317.  494. ...  420.  810. 1600.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[931. 137. 307. ... 212. 233. 499.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[624. 368. 652. ... 200. 228. 488.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[946. 433. 216. ... 203. 973.  13.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[  93.  148. 1009. ...  485. 1098.   65.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[255. 424. 129. ...  99. 214.  21.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1064.  370.  405. ...   76.   63. 1573.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[805.  74. 180. ... 517. 123.  51.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 290.   76. 1185. ...  182.   86.  213.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 490.   80.  821. ...  204.   21. 1621.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[494. 224. 528. ... 198. 295.  87.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 34. 193. 852. ... 415. 655. 272.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[436. 401. 483. ... 551. 411. 325.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1140.  258.  359. ...   47.  370.  261.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[470. 428. 414. ... 702. 591.  67.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 534.  238. 1181. ...  370.   84.  212.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[894.  59.  45. ... 472. 831. 114.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 751.   54.  138. ...  568.  156. 1568.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[369.  31. 818. ... 140. 484.   9.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[419. 268. 283. ... 146. 307.  83.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1264.   57.  293. ...   83.  688. 1551.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[369. 544. 929. ... 278. 464. 703.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[303.  99. 227. ... 566. 509.  75.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1027.    5.  139. ...  469.  145.  975.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[360. 539. 837. ...   9. 140.  74.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[878. 335.  44. ...  24. 553. 126.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[664. 825. 784. ... 261. 302.  33.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[921.  99. 476. ... 612. 397. 131.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 238.    2.  100. ... 1016.   88.  147.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[382. 842. 898. ... 452. 508.  68.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 40. 140. 710. ... 524. 382. 559.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 928.   99.  429. ...  781.  420. 1463.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[939.  49. 223. ... 199. 645.  89.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[886. 255.  63. ... 259. 682. 346.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[641.  34.  46. ... 790. 848. 444.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1138.  151.  429. ...  583.  460. 1488.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 79. 732. 795. ... 119.  22. 736.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[343. 237. 263. ...  75. 528.  79.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[460. 448. 925. ...  30. 651. 467.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[  39.   10.  111. ...  243.   65. 1353.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 15. 143. 176. ... 123.  30. 140.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1039.    9.   31. ...  931.   71.   53.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[837.   5.   0. ...  47. 190. 401.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1211.  328.  258. ...  687.    9.  202.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 322.   17. 1022. ...   39.  182.  173.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 627.  406.  196. ...   63.  349. 1529.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 62. 636. 964. ... 204. 131. 864.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1131.  289.  257. ...   94.   70.  187.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[201. 381. 158. ...  56.  84. 261.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[544. 719. 700. ... 172. 992. 304.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 920.   18.  379. ...  145.  532. 1474.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# ...
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[691. 219. 964. ... 419. 360. 133.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 690.   37.  253. ...  462. 1055.  110.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 48. 554. 719. ...  35.  65. 685.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[652. 540.  88. ... 706. 157. 794.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 48.  41. 498. ... 329. 323. 179.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 80. 155. 336. ...  92. 199. 146.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 238.  877. 1063. ...  165.   52.  409.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 261.   79.   29. ...  534.  150. 1498.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[509. 609. 586. ...  76. 769. 376.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[765. 364. 147. ...  50. 338. 305.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1105.  278.  320. ...  277.   45. 1457.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1021.  370.   53. ...  796.  274.  315.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 196.   29. 1155. ...  436.  108.  651.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[337. 464. 178. ...  16. 355. 186.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[763.  80.  12. ... 172. 112.  81.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 381.   48.    9. ...  353.   82. 1033.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[134. 720. 744. ... 530. 758. 144.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[786.  86. 201. ... 760.   3. 258.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 306.  290. 1145. ...  494.  832.   18.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[454. 711. 739. ... 253.   0. 622.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[481. 390. 141. ...  59. 746.  96.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1031.  115.  363. ...  166.  440. 1516.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 18. 652.  37. ...  19. 123. 322.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[535. 317. 231. ... 833.  15.  76.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[193.   7. 386. ... 156. 528. 116.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 861.  368.   19. ...   50.  134. 1451.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[397.  45. 209. ...  30. 636.  63.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[610. 128. 181. ... 172. 673. 296.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[171. 233. 367. ... 391.  88. 183.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[238. 594. 860. ...  87. 290. 370.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[392. 405. 662. ...  26. 732.  71.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 962.  191.  852. ...  490.  110. 1527.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[  59.  335. 1096. ...   23.  250.  728.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[884. 541. 346. ... 590. 131.  88.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 88. 320.   2. ... 150. 623.  87.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[  51.  532.  696. ...  458. 1164.   90.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 149.  187. 1041. ...    3.  532.   74.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# /Users/boris/miniconda3/lib/python3.12/site-packages/matrix_factorization/recommender_base.py:134: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1053.  157.  307. ...   92.  223. 1454.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X.loc[:, "item_id"] = X["item_id"].map(self.item_id_map)
# GridSearchCV(cv=5, estimator=KernelMF(gamma=0.01, verbose=0), n_jobs=-1,
#              param_grid={'kernel': ['linear', 'sigmoid', 'rbf'],
#                          'n_epochs': [10, 20, 50], 'n_factors': [10, 20, 50],
#                          'reg': [0, 0.005, 0.1]},
#              scoring='neg_root_mean_squared_error', verbose=1)

# %%
grid_search.best_score_
grid_search.best_params_
# Out:
# -0.9259453454713402
# {'kernel': 'linear', 'n_epochs': 50, 'n_factors': 50, 'reg': 0.1}
